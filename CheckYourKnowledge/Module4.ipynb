# %% [markdown]
# # Questions

# %% [markdown]
# ##### Question Batch 1

# %% [raw]
# 1. Why do we consider K-means clustering as a unsupervised machine learning algorithm?
#
# 2. How do you use “pair-wise” plots to evaluate the effectveness of the clustering?
#
# 3. Detail the four steps in the K-means clustering algorithm.
#
# 4. How do we use WSS to pick the value of K?
#
# 5. What is the most common measure of distance used with K-means clustering algorithms?
#
# 6. The attributes of a data set are “purchase decision (Yes/No), Gender (M/F), income group (<10K, 10-50K, >50K). Can you use K-means to cluster this data set?

# %% [raw]
# 1. K-Means is an unsupervised ml algorithm as it does not have class lables.
#
# 2. If there are not too many variables, pair-wise plots can be used to evaluate the effectiveness of algorithm. Clusters should look separated at least on some of the plots.
#
# 3.  a. Choose the number of clusters K; then select randomly the K centroids.
#     b. Assign records to the cluster with the closest centroid (Distance Measure).
#     c. Recalculate the resulting centroids as the mean value of all the points in the cluster
#     d. Repeat steps 2 and 3 until record assignments no longer change.
#
# 4. Within sum of squares (wss) is a function that calculates the total inertia within the clusters with respect to the number of clusters. Plotting this function and locating the “elbows” would help in picking K value.
#
# 5. Euclidean distance
#
# 6. Not before performing binarization, as this data is categorical.

# %% [markdown]
# ##### Question Batch 2

# %% [raw]
# 1. What is the Apriori property and how is it used in the Apriori algorithm?
#
# 2. List three popular use cases of the Associa3on Rules mining algorithms.
#
# 3. What is the difference between Lift and Leverage. How is Lip used in evaluatng the quality of rules discovered?
#
# 4. Define Support and Confidence
#
# 5. How do you use a “hold-out” dataset to evaluate the effectiveness of the rules generated?

# %% [raw]
# 1. Apriori property states that “Any subset of a frequent set is also frequent” and it is used to know how prune is the search space. In simple words, if an item is not frequent, we can throw it away, because it will not appear in any bigger frequent subsets.
#
# 2. Popular use cases of Association rules:
#     a. Market basket analysis
#     b. Recommender systems
#     c. Web usage patterns
#
# 3.	Lift measures how many times more often X and Y occur together than expected if they were statistically independent.Leverage is the difference in the probability of X and Y appearing together in the data set compared to what would be expected if X and Y were statistically independent.Lift being close to 1 indicates that the rule is purely coincidential. Greater lift shows that the rule is true and not coincidential.
#
# 4. The support value of an item set is defined as the proportion of transactions in the database which contains the item set.The confidence value if a rule (e.g. X -> Y) is the proportion of the transactions that contains X and also contains Y.
#
# 5. Generate a testing set, leave some values missing and see if the association rules can predict the missing values.

# %% [markdown]
# ##### Question Batch 3

# %% [raw]
# 1. How is the measure of significance used in determining the explanatory value of a driver (input variable) with linear regression models?
#
# 2. Detail the challenges with categorical values in linear regression model.
#
# 3. Describe N-Fold cross valida3on method used for diagnosing a fihed model.
#
# 4. List two use cases of linear regression models.
#
# 5. List and discuss two standard checks that you will perform on the coefficients derived from a linear regression model.

# %% [raw]
# 1. Statistical significance (p-value) is used to test if the variable should remain in the model. If p-value is low, hypothesis is rejected, so the variable should stay. Is it is high, the variable should be removed from the model.
#
# 2. To represent a categorical variable with n modalities, n-1 binary variables (each representing a modality) to the model, with the last category represented by setting all the binary values to zero.
#
# 3. N-Fold cross validation.
# The set is divided into N equal subsets. Then N-1 subsets are used as a training set and the 1 remaining is used as a testing set. Repeat N times with different testing sets and average the error.
#
# 4. a. Calculate the risk of having a car accident for an insurance company, based on the customer’s personal data
#    b. Calculate the probability of having a disease, based on a patient’s test results.
#
# 5. a. Statistical significance of each coefficient
#    b. Interpreting the Estimated Coefficients

# %% [markdown]
# ##### Question Batch 4

# %% [raw]
# 1. What is a logit and how do we compute class probabilities from the logit?
#
# 2. How is ROC curve used to diagnose the effectveness of the logistic regression model?
#
# 3. What is Pseudo R2 and what does it measure in a logistic regression model?
#
# 4. How do you describe a binary class problem?
#
# 5. Compare and contrast linear and logistc regression methods.

# %% [raw]
# 1. logit to estmate the probability that an event will occur as a funtion of other variables.
# logit is basically = 1/(1 + e^-x)
#
# 2. By default 0.5 is the default threshold. Using ROC curve we can decide on the threshold tradeoff value based on TPR and FPR.
#
# 3. Pseudo-R2 measures how well fitted model explains the data. (Value near 1 indicates a good fit over the null model)
#
# 4. A binary class broblem can have only two class labels. For Example (Male, Female), (0,1) , (Survived or Dead) etc.

# %%
from IPython.display import Image
Image(filename='/Users/krishna/Desktop/nb2.png')

# %% [markdown]
# ##### Question Batch 5

# %% [raw]
# 1. Answer the question in the image below

# %%
from IPython.display import Image
Image(filename='/Users/krishna/Desktop/nb.png')

# %% [raw]
# 2. List some prominent use cases of the Naïve Bayesian Classifier.
#
# 3. What gives the Naïve Bayesian Classifier the advantage of being computatonally inexpensive?
#
# 4. Why should we use log-likelihoods rather than pure probability values in the Naïve Bayesian Classifier?
#
# 5. What is a confusion matrix and how it is used to evaluate the effectveness of the model?
#
# 6. Consider the following data set with two input features temperature and season
# • What is the Naïve Bayesian assumpton?
# • Is the Naïve Bayesian assumption satsfied for this problem?

# %% [raw]
# 1. Answer 1
# library(e1071)
# train = read.csv("/Users/krishna/Dropbox/DMKM/Course/SEM2/BigDataAnalytics/data.txt",header = F)
# test = read.csv("/Users/krishna/Dropbox/DMKM/Course/SEM2/BigDataAnalytics/test.txt",header = F)
# model <- naiveBayes(as.factor(V3) ~ ., data = train,laplace = 0)
# predict(model, test)
#
# 2. Spam Filtering, Sentiment Analysis, Fraud Detection
#
# 3. Naive Assumption that the features are conditionally independent.
#
# 4. We should use log likelyhood to prevent Numerical underflow.
#
# 5. A confusion matrix shows the number of true positives (TP), false positives (FP), true negatives (TN), and false negatives (FN). This information can help us evaluate the performance of our model.
#
# 6. The assumptions are
#     a. Tempreature and Season are independent
#     b. No this assumption is wrong as in summer season the tempreature is generally hot. We see that there is a dependence between the two variables

# %% [markdown]
# ##### Question Batch 6

# %%
from IPython.display import Image
Image(filename='/Users/krishna/Desktop/nb1.png')

# %% [raw]
# 1. How do you define informaion gain?
#
# 2. For what conditons is the value of entropy at a maximum and when is it at a minimum?
#
# 3. List three use cases of Decision Trees.
#
# 4. What are weak learners and how are they used in ensemble methods?
#
# 5. Why do we end up with an over fitted model with deep trees and in data sets when we have outcomes that are dependent on many variables?
#
# 6. What classificaton method would you recommend for the following cases:
# High dimensional data
# Data in which outputs are affected by non-linearity and discontnuity in the inputs

# %% [raw]
# 1. We want to determine which attribute in a given set of training feature vectors is most useful for discriminating between the classes to be learned.
# Information gain tells us how important a given attribute of the feature vectors is. We will use it to decide the ordering of attributes in the nodes of a decision tree.
#
# 2. Entopy measures the level of impurity. When examples belong to the same class we have Minimum impurtiy. When examples 50% are in either class we have Maximum impurity (good training set for learning).
#
# 3. Credit Prediction, Housing Loan Application, Biological species classification, Fraud detection.
#
# 4. A 'weak' learner (classifer, predictor, etc) is just one which performs relatively poorly--its accuracy is above chance, but just barely. There is often, but not always, the added implication that it is computationally simple. Weak learner also suggests that many instances of the algorithm are being pooled (via boosting, bagging, etc) together into to create a "strong" ensemble classifier.
#
# 5. Deep trees tend to fit the data exactly. They do not generallize well. Hence we prune the leaves to prevent overfillting.
#
# 6. a) SVM , b) Random Forest
